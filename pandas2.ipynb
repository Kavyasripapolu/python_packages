# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mohan rao papolu\Downloads\Cost_of_Living_Index_by_Country_2024.csv",usecols=['Rank','Country','Cost of Living Index','Rent Index'])

# %%
df.head()
# Out:
#    Rank      Country  Cost of Living Index  Rent Index
# 0     1  Switzerland                 101.1        46.5
# 1     2      Bahamas                  85.0        36.7
# 2     3      Iceland                  83.0        39.2
# 3     4    Singapore                  76.7        67.2
# 4     5     Barbados                  76.6        19.0

# %%
df.head(10)
# Out:
#    Rank            Country  Cost of Living Index  Rent Index
# 0     1        Switzerland                 101.1        46.5
# 1     2            Bahamas                  85.0        36.7
# 2     3            Iceland                  83.0        39.2
# 3     4          Singapore                  76.7        67.2
# 4     5           Barbados                  76.6        19.0
# 5     6             Norway                  76.0        26.2
# 6     7            Denmark                  72.3        26.4
# 7     8  Hong Kong (China)                  70.8        59.4
# 8     9      United States                  70.4        41.7
# 9    10          Australia                  70.2        33.4

# %%
df.isnull()
# Out:
#       Rank  Country  Cost of Living Index  Rent Index  \
# 0    False    False                 False       False
# 1    False    False                 False       False
# 2    False    False                 False       False
# 3    False    False                 False       False
# 4    False    False                 False       False
# ..     ...      ...                   ...         ...
# 116  False    False                 False       False
# 117  False    False                 False       False
# 118  False    False                 False       False
# 119  False    False                 False       False
# 120  False    False                 False       False
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             False            False                   False
# 1                             False            False                   False
# 2                             False            False                   False
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Country                 0
# Cost of Living Index    0
# Rent Index              0
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)
print(df.isnull().sum())
# Out:
# Rank                    0
# Country                 0
# Cost of Living Index    0
# Rent Index              0
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)
print(df.head())
print(df.isnull().sum())
# Out:
#    Rank      Country  Cost of Living Index  Rent Index
# 0     1  Switzerland                 101.1        46.5
# 1     2      Bahamas                  85.0        36.7
# 2     3      Iceland                  83.0        39.2
# 3     4    Singapore                  76.7        67.2
# 4     5     Barbados                  76.6        19.0
# Rank                    0
# Country                 0
# Cost of Living Index    0
# Rent Index              0
# dtype: int64

# %%
mean_value=df['Cost of Living Index'].mean()
print(mean_value)
# Out:
# 43.555371900826444

# %%
median=df['Cost of Living Index'].median()
print(median)
# Out:
# 39.5

# %%
df.rename(columns={'Cost of Living Index':'cost of LI'},inplace=True)
print(df.head())
# Out:
#    Rank      Country  cost of LI  Rent Index
# 0     1  Switzerland       101.1        46.5
# 1     2      Bahamas        85.0        36.7
# 2     3      Iceland        83.0        39.2
# 3     4    Singapore        76.7        67.2
# 4     5     Barbados        76.6        19.0

# %%
df.mode()
# Out:
#      Rank     Country  cost of LI  Rent Index
# 0       1     Albania        26.4         7.7
# 1       2     Algeria         NaN         NaN
# 2       3   Argentina         NaN         NaN
# 3       4     Armenia         NaN         NaN
# 4       5   Australia         NaN         NaN
# ..    ...         ...         ...         ...
# 116   117     Uruguay         NaN         NaN
# 117   118  Uzbekistan         NaN         NaN
# 118   119   Venezuela         NaN         NaN
# 119   120     Vietnam         NaN         NaN
# 120   121    Zimbabwe         NaN         NaN
#
# [121 rows x 4 columns]

# %%
mean_value=df['Rent Index'].mean()
print(mean_value)
# Out:
# 16.05289256198347

# %%
df['Rent Index'].value_counts()
# Out:
# Rent Index
# 7.7     4
# 11.2    3
# 10.0    3
# 7.6     3
# 10.6    2
#        ..
# 16.7    1
# 24.2    1
# 14.1    1
# 24.8    1
# 2.8     1
# Name: count, Length: 99, dtype: int64

# %%
import matplotlib.pyplot as plt
x =[3,6,6,4,7,8,5,2,5,1,6,8,5,7]
y =[1,8,3,8,4,3,8,6,4,5,3,1,0,9]
plt.plot(x,y)
plt.show()

# %%
x =[3,6,6,4,7,8,5,2,5,1,6,8,5,7]
y =[1,8,3,8,4,3,8,6,4,5,3,1,0,9]
plt.bar(x,y)
plt.show()

# %%
y=[1,8,3,8,4,3,8,6,4,5,3,1,0,9]
plt.hist(y)
plt.show()

# %%
x =[3,6,6,4,7,8,5,2,5,1,6,8,5,7]
y =[1,8,3,8,4,3,8,6,4,5,3,1,0,9]
plt.scatter(x,y)
plt.show()

# %%
labels={'maths','physics','chemistry'}
sizes=[45,55,65]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.title('Subjects')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [1,2,3,4,5,6,7,8]
y1 = [2,4,6,8,10,12,14,16] 
y2 = [3,6,9,12,15,18,21,24] 
plt.fill_between(x, y1, y2, color='pink', alpha=0.4 , label='Area 1-2')
plt.plot(x, y1, label='Line 1', marker='o') 
plt.plot(x, y2, label='Line 2', marker='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('area chart')
plt.legend()
plt.show()

# %%
import numpy as np
fig,a= plt.subplots(2, 2)
x=np.arange(1,5)
a[0][0].plot(x,x*x)
a[0][0].set_title('Square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('Square Root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# %%
fig=plt.figure(figsize=(3,3),facecolor='pink',layout='constrained')
fig.suptitle('Figure')
ax=fig.add_subplot()
ax.set_title('Axea',loc='left', fontstyle='italic',fontsize='medium')
# Out:
# Text(0.0, 1.0, 'Axea')

# %%
fig=plt.finger()
ax1=fig.add_subplot(111)
ax1.plot([1,2,3])
ax2=fig.add_subplot(221,facecolor='p')
ax2.plot([

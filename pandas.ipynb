# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\mohan rao papolu\\Downloads\\archive.csv")
print(df)
# Out:
#              Language         Family            Region   Speakers  \
# 0              Yoruba  Indo-European             India   76000000
# 1        Southern Min  Indo-European             India   47000000
# 2     Yue (Cantonese)      Dravidian             India   75000000
# 3             Spanish   Austronesian            Poland   76900000
# 4              Arabic  Indo-European         Worldwide   76000000
# ..                ...            ...               ...        ...
# 495           Punjabi   Indo-Iranian             India   23000000
# 496           Spanish      Dravidian         Worldwide   76900000
# 497           English  Indo-European  Germany, Austria   28000000
# 498  Xiang (Hunanese)  Indo-European         Worldwide  460000000
# 499           Punjabi  Indo-European         Indonesia   83000000
#
#     Writing System ISO Code
# 0            Latin       om
# 1            Latin       ru
# 2       Devanagari       my
# 3       Devanagari       it
# ...

# %%
df.head(10)
# Out:
#             Language         Family       Region  Speakers  \
# 0             Yoruba  Indo-European        India  76000000
# 1       Southern Min  Indo-European        India  47000000
# 2    Yue (Cantonese)      Dravidian        India  75000000
# 3            Spanish   Austronesian       Poland  76900000
# 4             Arabic  Indo-European    Worldwide  76000000
# 5             Awadhi        Kra-Dai      Vietnam  57000000
# 6  Wu (Shanghainese)       Koreanic        China  22000000
# 7    Yue (Cantonese)   Afro-Asiatic    Worldwide  26000000
# 8           Javanese      Dravidian      Nigeria  23000000
# 9            Italian  Indo-European  Philippines  60000000
#
#        Writing System ISO Code
# 0               Latin       om
# 1               Latin       ru
# 2          Devanagari       my
# 3          Devanagari       it
# 4              Hangul       ur
# 5               Latin       it
# 6  Simplified Chinese       bn
# 7          Devanagari      hak
# ...

# %%
df.tail(45)
# Out:
#              Language         Family                     Region   Speakers  \
# 455            Pashto  Indo-European  Middle East, North Africa   50000000
# 456             Hindi  Indo-European            India, Pakistan   34000000
# 457              Igbo      Dravidian                      Italy   23000000
# 458              Igbo    Niger-Congo                  Worldwide   35000000
# 459            Yoruba   Austronesian                   Ethiopia   27000000
# 460           Bengali   Sino-Tibetan            India, Pakistan   24000000
# 461          Gujarati  Indo-European                      China  125000000
# 462           Tagalog  Indo-European                    Ukraine   23000000
# 463   Yue (Cantonese)    Niger-Congo                      China  341000000
# 464            Awadhi   Sino-Tibetan                      Korea  341000000
# 465          Romanian  Indo-European                Philippines   25000000
# ...

# %%
df.describe()
# Out:
#            Speakers
# count  5.000000e+02
# mean   9.840200e+07
# std    1.414893e+08
# min    2.000000e+07
# 25%    2.800000e+07
# 50%    5.350000e+07
# 75%    7.690000e+07
# max    9.180000e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Language        500 non-null    object
#  1   Family          500 non-null    object
#  2   Region          500 non-null    object
#  3   Speakers        500 non-null    int64
#  4   Writing System  500 non-null    object
#  5   ISO Code        489 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 23.6+ KB

# %%
print(df.shape)
print(df.shape[0]) 
print(df.shape[1])
# Out:
# (500, 6)
# 500
# 6

# %%
list(df.columns)
# Out:
# ['Language', 'Family', 'Region', 'Speakers', 'Writing System', 'ISO Code']

# %%
df.columns
# Out:
# Index(['Language', 'Family', 'Region', 'Speakers', 'Writing System',
#        'ISO Code'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      Language  Family  Region  Speakers  Writing System  ISO Code
# 0       False   False   False     False           False     False
# 1       False   False   False     False           False     False
# 2       False   False   False     False           False     False
# 3       False   False   False     False           False     False
# 4       False   False   False     False           False     False
# ..        ...     ...     ...       ...             ...       ...
# 495     False   False   False     False           False     False
# 496     False   False   False     False           False     False
# 497     False   False   False     False           False     False
# 498     False   False   False     False           False     False
# 499     False   False   False     False           False     False
#
# [500 rows x 6 columns]

# %%
df.isnull().head()
# Out:
#    Language  Family  Region  Speakers  Writing System  ISO Code
# 0     False   False   False     False           False     False
# 1     False   False   False     False           False     False
# 2     False   False   False     False           False     False
# 3     False   False   False     False           False     False
# 4     False   False   False     False           False     False

# %%
df.isnull().head(45)
# Out:
#     Language  Family  Region  Speakers  Writing System  ISO Code
# 0      False   False   False     False           False     False
# 1      False   False   False     False           False     False
# 2      False   False   False     False           False     False
# 3      False   False   False     False           False     False
# 4      False   False   False     False           False     False
# 5      False   False   False     False           False     False
# 6      False   False   False     False           False     False
# 7      False   False   False     False           False     False
# 8      False   False   False     False           False     False
# 9      False   False   False     False           False     False
# 10     False   False   False     False           False     False
# 11     False   False   False     False           False     False
# 12     False   False   False     False           False     False
# ...

# %%
df.isnull().sum()
# Out:
# Language           0
# Family             0
# Region             0
# Speakers           0
# Writing System     0
# ISO Code          11
# dtype: int64

# %%
df.isna()
# Out:
#      Language  Family  Region  Speakers  Writing System  ISO Code
# 0       False   False   False     False           False     False
# 1       False   False   False     False           False     False
# 2       False   False   False     False           False     False
# 3       False   False   False     False           False     False
# 4       False   False   False     False           False     False
# ..        ...     ...     ...       ...             ...       ...
# 495     False   False   False     False           False     False
# 496     False   False   False     False           False     False
# 497     False   False   False     False           False     False
# 498     False   False   False     False           False     False
# 499     False   False   False     False           False     False
#
# [500 rows x 6 columns]

# %%
df['Language']
# Out:
# 0                Yoruba
# 1          Southern Min
# 2       Yue (Cantonese)
# 3               Spanish
# 4                Arabic
#              ...
# 495             Punjabi
# 496             Spanish
# 497             English
# 498    Xiang (Hunanese)
# 499             Punjabi
# Name: Language, Length: 500, dtype: object

# %%
df[['Language','Family','Region','Speakers']]
# Out:
#              Language         Family            Region   Speakers
# 0              Yoruba  Indo-European             India   76000000
# 1        Southern Min  Indo-European             India   47000000
# 2     Yue (Cantonese)      Dravidian             India   75000000
# 3             Spanish   Austronesian            Poland   76900000
# 4              Arabic  Indo-European         Worldwide   76000000
# ..                ...            ...               ...        ...
# 495           Punjabi   Indo-Iranian             India   23000000
# 496           Spanish      Dravidian         Worldwide   76900000
# 497           English  Indo-European  Germany, Austria   28000000
# 498  Xiang (Hunanese)  Indo-European         Worldwide  460000000
# 499           Punjabi  Indo-European         Indonesia   83000000
#
# [500 rows x 4 columns]

# %%
df[df.index == 336]
# Out:
#               Language  Family   Region  Speakers Writing System ISO Code
# 336  Wu (Shanghainese)  Turkic  Nigeria  25000000       Cyrillic       my

# %%
df[df.index.isin(range(9,45))]
# Out:
#            Language         Family                  Region   Speakers  \
# 9           Italian  Indo-European             Philippines   60000000
# 10           German         Turkic                   China   27000000
# 11          English      Dravidian                   India   83000000
# 12         Romanian  Indo-European        Portugal, Brazil   47000000
# 13          Marathi   Sino-Tibetan                 Nigeria   67000000
# 14        Malayalam  Indo-European               Worldwide   35000000
# 15          Bengali   Sino-Tibetan                 Romania   25000000
# 16         Bhojpuri   Sino-Tibetan                   China   77000000
# 17        Ukrainian    Niger-Congo         Pakistan, India  128000000
# 18          Amharic         Turkic               Indonesia  341000000
# 19          Burmese        Kra-Dai  Russia, Eastern Europe   25000000
# 20            Hausa  Indo-European        Portugal, Brazil   32000000
# ...

# %%
df.loc[45]
# Out:
# Language                Burmese
# Family            Indo-European
# Region                Indonesia
# Speakers               24000000
# Writing System            Oriya
# ISO Code                     te
# Name: 44, dtype: object

# %%
df.loc[111:222]
# Out:
#         Language         Family                 Region   Speakers  \
# 111     Gujarati   Sino-Tibetan              Indonesia   24000000
# 112         Fula  Indo-European                  India   82000000
# 113  Azerbaijani  Indo-European                Romania   67000000
# 114        Hindi  Indo-European                  India  128000000
# 115       Yoruba  Indo-European                Nigeria   47000000
# ..           ...            ...                    ...        ...
# 218       Sindhi  Indo-European                Myanmar   32000000
# 219     Bhojpuri         Turkic                 Turkey   82000000
# 220       Sindhi  Indo-European                  Korea   50000000
# 221   Vietnamese  Indo-European              Worldwide   50000000
# 222      Amharic  Indo-European  Afghanistan, Pakistan   47000000
#
#           Writing System ISO Code
# 111                Latin      awa
# 112  Traditional Chinese       de
# 113   Simplified Chinese       tr
# ...

# %%
df.loc[df.Region == 'India']
# Out:
#             Language         Family Region   Speakers       Writing System  \
# 0             Yoruba  Indo-European  India   76000000                Latin
# 1       Southern Min  Indo-European  India   47000000                Latin
# 2    Yue (Cantonese)      Dravidian  India   75000000           Devanagari
# 11           English      Dravidian  India   83000000  Traditional Chinese
# 21           Burmese  Austroasiatic  India  460000000              Chinese
# ..               ...            ...    ...        ...                  ...
# 483         Mandarin  Indo-European  India   60000000                Latin
# 487           Telugu   Sino-Tibetan  India   27000000                Latin
# 489          Punjabi         Turkic  India  274000000                Latin
# 492     Southern Min  Indo-European  India   83000000  Traditional Chinese
# 495          Punjabi   Indo-Iranian  India   23000000                Latin
#
#     ISO Code
# 0         om
# 1         ru
# 2         my
# ...

# %%
df.iloc[45]
# Out:
# Language                 Romanian
# Family                   Koreanic
# Region            India, Pakistan
# Speakers                 24000000
# Writing System              Latin
# ISO Code                       ar
# Name: 45, dtype: object

# %%
df.iloc[9,4]
# Out:
# 'Hangul'

# %%
df.iloc[[9,18,27,36,45,54,63,72,81]]
# Out:
#      Language         Family            Region   Speakers  \
# 9     Italian  Indo-European       Philippines   60000000
# 18    Amharic         Turkic         Indonesia  341000000
# 27      Tamil   Austronesian             China   50000000
# 36     Awadhi  Indo-European             India   50000000
# 45   Romanian       Koreanic   India, Pakistan   24000000
# 54      Hindi  Indo-European        Uzbekistan   22000000
# 63  Ukrainian   Afro-Asiatic   Pakistan, India   75000000
# 72       Fula  Indo-European             India   83000000
# 81      Oromo    Niger-Congo  Portugal, Brazil  221000000
#
#                Writing System ISO Code
# 9                      Hangul       ig
# 18                     Telugu       pt
# 27                      Latin       sd
# 36                      Latin       ru
# 45                      Latin       ar
# 54                      Latin       it
# 63                    Chinese       de
# 72                      Latin      wuu
# ...

# %%
df.iloc[1: 4, 3: 5]
# Out:
#    Speakers Writing System
# 1  47000000          Latin
# 2  75000000     Devanagari
# 3  76900000     Devanagari

# %%
df.head(10)
# Out:
#             Language         Family       Region  Speakers  \
# 0             Yoruba  Indo-European        India  76000000
# 1       Southern Min  Indo-European        India  47000000
# 2    Yue (Cantonese)      Dravidian        India  75000000
# 3            Spanish   Austronesian       Poland  76900000
# 4             Arabic  Indo-European    Worldwide  76000000
# 5             Awadhi        Kra-Dai      Vietnam  57000000
# 6  Wu (Shanghainese)       Koreanic        China  22000000
# 7    Yue (Cantonese)   Afro-Asiatic    Worldwide  26000000
# 8           Javanese      Dravidian      Nigeria  23000000
# 9            Italian  Indo-European  Philippines  60000000
#
#        Writing System ISO Code
# 0               Latin       om
# 1               Latin       ru
# 2          Devanagari       my
# 3          Devanagari       it
# 4              Hangul       ur
# 5               Latin       it
# 6  Simplified Chinese       bn
# 7          Devanagari      hak
# ...
